# %%
import pandas as pd
import numpy as np
import re
import string
import kagglehub
import os 
import matplotlib.pyplot as plt
import seaborn as sns
import shutil

# %%
from pathlib import Path 
project_root = Path.cwd()
if project_root.name == "notebooks":
    project_root = project_root.parent

# %%
raw_dir = project_root/"data"/"raw"
raw_dir.mkdir(parents=True, exist_ok=True)

# %%
out_path = raw_dir / "news_dataset.json"

.to_json(out_path, orient="records", force_ascii=False, indent=2)

print(f"Saved to: {out_path}")
# Out:
# WindowsPath('d:/projects/vietnamese-news-search-engine/data/raw/news_dataset.json')
