# %%
import pandas as pd

# %%
data = pd.read_pickle("../data/news_dataset_df_prep3.pkl") 
data.head()
# Out:
#        id             author  \
# 0  218270
# 1  218269      (Nguồn: Sina)
# 2  218268          Hồ Sỹ Anh
# 3  218267           Ngọc Ánh
# 4  218266  HẢI YẾN - MINH LÝ
#
#                                              content  picture_count  \
# 0  Chiều 31/7, Công an tỉnh Thừa Thiên - Huế đã c...              3
# 1  Gần đây, Thứ trưởng Bộ Phát triển Kỹ thuật số,...              1
# 2  Kết quả thi tốt nghiệp THPT năm 2022 cho thấy ...              3
# 3  Thống đốc Kentucky Andy Beshear hôm 31/7 cho h...              1
# 4  Vụ tai nạn giao thông liên hoàn trên phố đi bộ...             12
#
#    processed        source                                              title  \
# 0          0     docbao.vn  Tên cướp tiệm vàng tại Huế là đại uý công an, ...
# 1          0        vtc.vn        Bỏ qua mạng 5G, Nga tiến thẳng từ 4G lên 6G
# 2          0  thanhnien.vn  Địa phương nào đứng đầu cả nước tổng điểm 3 mô...
# 3          0     vnexpress  Người chết trong mưa lũ 'nghìn năm có một' ở M...
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 160254 entries, 0 to 184538
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   160254 non-null  int64
#  1   author               160254 non-null  object
#  2   content              160254 non-null  object
#  3   picture_count        160254 non-null  int64
#  4   processed            160254 non-null  int64
#  5   source               160250 non-null  object
#  6   title                160254 non-null  object
#  7   topic                160254 non-null  object
#  8   url                  160254 non-null  object
#  9   crawled_at           159881 non-null  datetime64[ns]
#  10  title_processed      160254 non-null  object
#  11  content_processed    160254 non-null  object
#  12  combined_processed   160254 non-null  object
#  13  combined_unaccented  160254 non-null  object
# dtypes: datetime64[ns](1), int64(3), object(10)
# ...

# %%
data.to_json('../data/news_dataset.json', orient='records', force_ascii=False, indent=2)
print("Data exported to ./news_dataset.json")
# Out:
# C:\Users\PC MSI\AppData\Local\Temp\ipykernel_35068\2943464512.py:1: Pandas4Warning: The default 'epoch' date format is deprecated and will be removed in a future version, please use 'iso' date format instead.
#   data.to_json('./news_dataset.json', orient='records', force_ascii=False, indent=2)
# Data exported to ./news_dataset.json
